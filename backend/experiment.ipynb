# %%
from dotenv import load_dotenv
import os
load_dotenv()
ASSEMBY_API_KEY = os.getenv("ASSEMBLYAI_API_KEY")
print(ASSEMBY_API_KEY)
# Out:
# 63f6d41220564a4e9d3fc2af082069ae

# %%
import assemblyai as aai
file_path = r"C:\Users\Asus\Callagent\data\uploads\1735404531.458927.mp3"

transcriber = aai.Transcriber()

transcript = transcriber.transcribe(file_path)

print(transcript.text)
# Out:
# Hello? Hello. Hello, my name is Stephen. I'm calling you from finance department of online company. You were speaking with Michael before and Your manager is Mr. Omar, correct? Okay. All right. So, yeah, I was calling you to help you because we were trying to find a solution and a way to make very quick and easy withdrawal of your money on the platform back to your bank. So I think we finally found an option and that's why I'm calling you to help you with that. So it will just take another 5, 10 minutes of your time. If you're available, I would like to guide you through the steps and see if we can work out together. So are you available for me to help you with it? Yes. Okay, wonderful. Now I will ask you, please open any desk and give me the any desk on your computer. Okay. And the numbers. 1-5 1 5. Okay. I send a request. Okay, I will help you over here. Okay. Okay. I just close it. Of course, no problem. Okay. Okay. Now the name of the app is like this. It's a very colorful websit
# ...

# %%
from dotenv import load_dotenv
import os
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
print(GEMINI_API_KEY)
# Out:
# AIzaSyA9hQJTJ8lJcWnv4LMvEJ0_Im2Uc_jRijE

# %%
from app.database import engine

try:
    conn = engine.connect()
    print("✅ Database connected successfully")
    conn.close()
except Exception as e:
    print("❌ Database error:", e)
# Out:
# ✅ Database connected successfully

# %%
from dotenv import load_dotenv
import os
import google.genai as genai

# Load env
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

print("Gemini key loaded:", bool(GEMINI_API_KEY))

# Create client
client = genai.Client(api_key=GEMINI_API_KEY)

# ✅ USE THIS MODEL (IMPORTANT)
response = client.models.generate_content(
    model="models/gemini-pro-latest",
    contents="Explain what a call center analyzer does in one sentence."
)

print("\n✅ Gemini Response:\n")
print(response.text)
# Out:
# Gemini key loaded: True
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[17], line 15
#      12 client = genai.Client(api_key=GEMINI_API_KEY)
#      14 # ✅ USE THIS MODEL (IMPORTANT)
# ---> 15 response = client.models.generate_content(
#      16     model="models/gemini-pro-latest",
#      17     contents="Explain what a call center analyzer does in one sentence."
#      18 )
#      20 print("\n✅ Gemini Response:\n")
#      21 print(response.text)
#
# File c:\Users\Asus\Callagent\.venv\Lib\site-packages\google\genai\models.py:5203, in Models.generate_content(self, model, contents, config)
#    5201 while remaining_remote_calls_afc > 0:
#    5202   i += 1
# -> 5203   response = self._generate_content(
#    5204       model=model, contents=contents, config=parsed_config
#    5205   )
#    5207   function_map = _extra_utils.get_function_map(parsed_config)
# ...

# %%
import google.genai as genai
from dotenv import load_dotenv
import os

load_dotenv()
client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

models = client.models.list()

print("Available models:")
for m in models:
    print(m.name)
# Out:
# Available models:
# models/embedding-gecko-001
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# ...

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

BASE_DIR = Path(__file__).resolve().parent.parent.parent
ENV_PATH = BASE_DIR / ".env"

load_dotenv(dotenv_path=ENV_PATH)

print("DB_PASSWORD LOADED:", bool(os.getenv("1234")))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from pathlib import Path
#       3 from dotenv import load_dotenv
# ----> 5 BASE_DIR = Path(__file__).resolve().parent.parent.parent
#       6 ENV_PATH = BASE_DIR / ".env"
#       8 load_dotenv(dotenv_path=ENV_PATH)
#
# NameError: name '__file__' is not defined

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="callagent",
    user="postgres",
    password="1234"
)

print("CONNECTED SUCCESSFULLY")
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host="localhost",
#       5     port=5432,
#       6     database="callagent",
#       7     user="postgres",
#       8     password="1234"
#       9 )
#      11 print("CONNECTED SUCCESSFULLY")
#      12 conn.close()
#
# File c:\Users\Asus\Callagent\.venv\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# ...

# %%
import os
from dotenv import load_dotenv
DOTENV_TEST="hello123"
print("DOTENV_TEST:", os.getenv("DOTENV_TEST"))
print("DB_PASSWORD RAW:", repr(os.getenv("DB_PASSWORD")))
# Out:
# DOTENV_TEST: None
# DB_PASSWORD RAW: '0313'

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="postgres",
    user="postgres",
    password="Rads13"
)

print("DB CONNECTION SUCCESS")
conn.close()
# Out:
# DB CONNECTION SUCCESS
